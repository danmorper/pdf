# %% [markdown]
# # Summary PyPDF2

# %% [markdown]
# - Extracting text
# - Extract images
# - Encryption and Decryption
# - Rotating PDF pages
# - Merging PDFs
# - Adding and reading pdf annotations
# - Interacting with PDF forms
# - Splitting PDF
# - Adding watermark to PDF pages

# %%
import PyPDF2

reader = PyPDF2.PdfReader("ResultList_1.pdf")
print(help(reader))
# Out:
# Help on PdfReader in module PyPDF2._reader object:
#
# class PdfReader(builtins.object)
#  |  PdfReader(stream: Union[str, IO, pathlib.Path], strict: bool = False, password: Union[NoneType, str, bytes] = None) -> None
#  |
#  |  Initialize a PdfReader object.
#  |
#  |  This operation can take some time, as the PDF stream's cross-reference
#  |  tables are read into memory.
#  |
#  |  :param stream: A File object or an object that supports the standard read
#  |      and seek methods similar to a File object. Could also be a
#  |      string representing a path to a PDF file.
#  |  :param bool strict: Determines whether user should be warned of all
#  |      problems and also causes some correctable problems to be fatal.
#  |      Defaults to ``False``.
#  |  :param None/str/bytes password: Decrypt PDF file at initialization. If the
#  |      password is None, the file will not be decrypted.
#  |      Defaults to ``None``
#  |
#  |  Methods defined here:
#  |
# ...

# %% [markdown]
# # Text extraction

# %%
reader.pages[0] # first page
print(reader.pages[0].extract_text()) # text of first page
# Out:
# Splash Meet Manager, 11.77033 Registered to Andalucía 01/07/2023 11:48 - Página 1
# VIII TROFEO NAT. CADIZ -1ª LIGA VELOCIDAD (3ªJornada)
# CÁDIZ, 1/7/2023
# Prueba 1 Masc., 50m Mariposa 11 - 14 años
# 01/07/2023 - 11:00 Resultados
# Clasificación AN Tiempo Ptos. Ptos. FINA
# Benjamin Masc.
# 1.JIMÉNEZ FERNÁNDEZ, Jaime 11 C.N. Carmona 37.10 19,00 216,00
# 2.MARTÍNEZ DE MORENTIN SÁNCHEZ, P. 11 C.N. Carmona 37.14 16,00 215,00
# 3.GONZALEZ PRADA, Alonso 12 C.N. Portuense 56.40 14,00 61,00
# 4.CARO CUELLAR, Hugo 12 C.N. Portuense 1:00.38 13,00 50,00
# WDR GÓMEZ GUERRERO, Francisco 12 C.N. Carmona - -
# WDR CABRERA RUFIAN, Pepe 12 C.N. Portuense - -
# Alevín Masc.
# 1.GARCÍA LUCERO, Jorge 09 C.N. Portuense 31.63 19,00 349,00
# 2.EIZAGA GARCIA, Bruno 09 C.N. Cadiz 31.73 16,00 345,00
# 3.GONZÁLEZ PRADAS, Héctor 10 C.N. Portuense 31.88 14,00 340,00
# 4.JIMENEZ ROMAY, Victor 09 C.N. Portuense 32.83 13,00 312,00
# 5.LEONSEGUI ARCUSA, Miguel 09 C.N. Cadiz 34.06 12,00 279,00
# ...

# %% [markdown]
# # Image extraction

# %%
# pip install PyPDF2[image] nedeed for images
page = reader.pages[0]
count = 0

for image_file_object in page.images:
    with open(str(count) + image_file_object.name, "wb") as fp:
        fp.write(image_file_object.data)
        count += 1
# Out:
# File(name=Img20.jpg, data: 40.2 kB)

# %% [markdown]
# # Encrypting and decrypting PDFs

# %%
writer = PyPDF2.PdfWriter()

# Add all pages to the writer
for page in reader.pages:
    writer.add_page(page)

# Add a password to the new PDF
writer.encrypt("my-secret-password")

# Save the new PDF to a file
with open("encrypted-pdf.pdf", "wb") as f:
    writer.write(f)

# %%
writer = PyPDF2.PdfWriter()

if reader.is_encrypted:
    reader.decrypt("my-secret-password")

# Add all pages to the writer
for page in reader.pages:
    writer.add_page(page)

# Save the new PDF to a file
with open("decrypted-pdf.pdf", "wb") as f:
    writer.write(f)
